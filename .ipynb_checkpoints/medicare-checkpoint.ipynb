# %% [markdown]
# <h4>Antes de empezar</h4>

# %%
def warn(*args, **kwargs):
    pass

import warnings
warnings.warn = warn

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %% [markdown]
# <h1>Importar datos</h1>

# %%
import pandas as pd

xls = pd.ExcelFile('data/Y2015_33010.xlsx')
df = xls.parse('Y2015_33010', skiprows=4, index_col=None, na_values=['NaN'])
df = df.loc[:, ~df.columns.str.contains('Unnamed')]

# %%
df.head()
# Out:
#       DESCRIPTION    HCPCS MODIFIER  ALLOWED SERVICES  ALLOWED CHARGES  \
# 0  CARDIOVASCULAR  33010.0      80S               NaN             0.00
# 1  CARDIOVASCULAR  33010.0    OTHER            5151.0        562626.12
# 2  CARDIOVASCULAR  33010.0    TOTAL            5151.0        562626.12
# 3  CARDIOVASCULAR  33011.0      80S               NaN             0.00
# 4  CARDIOVASCULAR  33011.0    OTHER              84.0          9551.17
#
#      PAYMENT
# 0       0.00
# 1  436220.88
# 2  436220.88
# 3       0.00
# 4    7430.49

# %% [markdown]
# <h1>Preprocesamiento de datos</h1>
# <h3>1. Limpieza de datos</h3>

# %%
df = df[df['MODIFIER'] == 'TOTAL'].dropna()

# %%
df.head()
# Out:
#        DESCRIPTION    HCPCS MODIFIER  ALLOWED SERVICES  ALLOWED CHARGES  \
# 2   CARDIOVASCULAR  33010.0    TOTAL            5151.0        562626.12
# 5   CARDIOVASCULAR  33011.0    TOTAL              84.0          9551.17
# 8   CARDIOVASCULAR  33015.0    TOTAL            1025.0        497290.05
# 11  CARDIOVASCULAR  33020.0    TOTAL             270.0        165726.14
# 14  CARDIOVASCULAR  33025.0    TOTAL            6653.0       4070839.95
#
#        PAYMENT
# 2    436220.88
# 5      7430.49
# 8    387598.81
# 11   127293.22
# 14  3162574.29

# %%
df.describe()
# Out:
#               HCPCS  ALLOWED SERVICES  ALLOWED CHARGES       PAYMENT
# count   5068.000000      5.068000e+03     5.068000e+03  5.068000e+03
# mean   39518.161405      3.394709e+04     4.409164e+06  3.390012e+06
# std    15989.769082      7.979756e+05     3.663517e+07  2.825897e+07
# min    10021.000000      1.100000e+01     1.354800e+02  8.981000e+01
# 25%    27095.750000      1.090000e+02     5.887076e+04  4.578995e+04
# 50%    35696.000000      5.095000e+02     2.492534e+05  1.926762e+05
# 75%    52317.250000      2.966750e+03     1.221123e+06  9.406879e+05
# max    69990.000000      5.223577e+07     2.147711e+09  1.664104e+09

# %%
df.shape
# Out:
# (5068, 6)

# %% [markdown]
# <h3>2. Analizar transformaciones de variables</h3>

# %%
df['AVERAGE ALLOWED CHARGES'] = df['ALLOWED CHARGES'] / df['ALLOWED SERVICES']
df['AVERAGE PAYMENT'] = df['PAYMENT'] / df['ALLOWED SERVICES']

# %%
df.head()
# Out:
#        DESCRIPTION    HCPCS MODIFIER  ALLOWED SERVICES  ALLOWED CHARGES  \
# 2   CARDIOVASCULAR  33010.0    TOTAL            5151.0        562626.12
# 5   CARDIOVASCULAR  33011.0    TOTAL              84.0          9551.17
# 8   CARDIOVASCULAR  33015.0    TOTAL            1025.0        497290.05
# 11  CARDIOVASCULAR  33020.0    TOTAL             270.0        165726.14
# 14  CARDIOVASCULAR  33025.0    TOTAL            6653.0       4070839.95
#
#        PAYMENT  AVERAGE ALLOWED CHARGES  AVERAGE PAYMENT
# 2    436220.88               109.226581        84.686639
# 5      7430.49               113.704405        88.458214
# 8    387598.81               485.161024       378.145180
# 11   127293.22               613.800519       471.456370
# 14  3162574.29               611.880347       475.360633

# %%
df.describe()
# Out:
#               HCPCS  ALLOWED SERVICES  ALLOWED CHARGES       PAYMENT  \
# count   5068.000000      5.068000e+03     5.068000e+03  5.068000e+03
# mean   39518.161405      3.394709e+04     4.409164e+06  3.390012e+06
# std    15989.769082      7.979756e+05     3.663517e+07  2.825897e+07
# min    10021.000000      1.100000e+01     1.354800e+02  8.981000e+01
# 25%    27095.750000      1.090000e+02     5.887076e+04  4.578995e+04
# 50%    35696.000000      5.095000e+02     2.492534e+05  1.926762e+05
# 75%    52317.250000      2.966750e+03     1.221123e+06  9.406879e+05
# max    69990.000000      5.223577e+07     2.147711e+09  1.664104e+09
#
#        AVERAGE ALLOWED CHARGES  AVERAGE PAYMENT
# count              5068.000000      5068.000000
# mean                625.739146       485.280287
# std                 545.394788       424.973247
# min                   2.999717         2.929552
# 25%                 254.367483       195.990117
# 50%                 492.231567       381.338796
# 75%                 828.012836       640.126760
# max                8460.605567      6591.287453

# %%
df.shape
# Out:
# (5068, 8)

# %%
import seaborn as sns

df['AVERAGE ALLOWED CHARGES'].plot(kind='hist')
plt.xlabel('AVERAGE ALLOWED CHARGES')
plt.show()

df['AVERAGE PAYMENT'].plot(kind='hist')
plt.xlabel('AVERAGE PAYMENT')
plt.show()

sns.set(style='whitegrid')
ax_aac = sns.boxplot(x=df['AVERAGE ALLOWED CHARGES'])
plt.show()

sns.set(style='whitegrid')
ax_ap = sns.boxplot(x=df['AVERAGE PAYMENT'])
plt.show()

df['DESCRIPTION'].value_counts().plot(kind='bar')
plt.xlabel('DESCRIPTION')
plt.show()

# %% [markdown]
# <h4>Cambio de la variable categórica a numérica</h4>

# %%
one_hot = pd.get_dummies(df['DESCRIPTION'])
df = df.drop('DESCRIPTION',axis = 1)
df = df.join(one_hot)

# %%
df.head()
# Out:
#       HCPCS MODIFIER  ALLOWED SERVICES  ALLOWED CHARGES     PAYMENT  \
# 2   33010.0    TOTAL            5151.0        562626.12   436220.88
# 5   33011.0    TOTAL              84.0          9551.17     7430.49
# 8   33015.0    TOTAL            1025.0        497290.05   387598.81
# 11  33020.0    TOTAL             270.0        165726.14   127293.22
# 14  33025.0    TOTAL            6653.0       4070839.95  3162574.29
#
#     AVERAGE ALLOWED CHARGES  AVERAGE PAYMENT  CARDIOVASCULAR  \
# 2                109.226581        84.686639               1
# 5                113.704405        88.458214               1
# 8                485.161024       378.145180               1
# 11               613.800519       471.456370               1
# 14               611.880347       475.360633               1
#
#     DIGESTIVE SYSTEM  EAR  ...  EYE  FEMALE GENITALIA  INTEGUMENTARY  \
# 2                  0    0  ...    0                 0              0
# 5                  0    0  ...    0                 0              0
# 8                  0    0  ...    0                 0              0
# 11                 0    0  ...    0                 0              0
# 14                 0    0  ...    0                 0              0
#
#     LYMPHATIC  MALE GENITALIA  MATERNITY  MEDIASTINUM  MUSCULOSKELETAL  \
# 2           0               0          0            0                0
# 5           0               0          0            0                0
# 8           0               0          0            0                0
# 11          0               0          0            0                0
# 14          0               0          0            0                0
#
#     RESPIRATORY  URINARY
# 2             0        0
# 5             0        0
# 8             0        0
# 11            0        0
# 14            0        0
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#               HCPCS  ALLOWED SERVICES  ALLOWED CHARGES       PAYMENT  \
# count   5068.000000      5.068000e+03     5.068000e+03  5.068000e+03
# mean   39518.161405      3.394709e+04     4.409164e+06  3.390012e+06
# std    15989.769082      7.979756e+05     3.663517e+07  2.825897e+07
# min    10021.000000      1.100000e+01     1.354800e+02  8.981000e+01
# 25%    27095.750000      1.090000e+02     5.887076e+04  4.578995e+04
# 50%    35696.000000      5.095000e+02     2.492534e+05  1.926762e+05
# 75%    52317.250000      2.966750e+03     1.221123e+06  9.406879e+05
# max    69990.000000      5.223577e+07     2.147711e+09  1.664104e+09
#
#        AVERAGE ALLOWED CHARGES  AVERAGE PAYMENT  CARDIOVASCULAR  \
# count              5068.000000      5068.000000     5068.000000
# mean                625.739146       485.280287        0.116614
# std                 545.394788       424.973247        0.320992
# min                   2.999717         2.929552        0.000000
# 25%                 254.367483       195.990117        0.000000
# 50%                 492.231567       381.338796        0.000000
# 75%                 828.012836       640.126760        0.000000
# max                8460.605567      6591.287453        1.000000
#
#        DIGESTIVE SYSTEM          EAR  ENDOCRINE SYSTEM          EYE  \
# count       5068.000000  5068.000000       5068.000000  5068.000000
# mean           0.154696     0.015785          0.095896     0.054262
# std            0.361650     0.124656          0.294477     0.226556
# min            0.000000     0.000000          0.000000     0.000000
# 25%            0.000000     0.000000          0.000000     0.000000
# 50%            0.000000     0.000000          0.000000     0.000000
# 75%            0.000000     0.000000          0.000000     0.000000
# max            1.000000     1.000000          1.000000     1.000000
#
#        FEMALE GENITALIA  INTEGUMENTARY    LYMPHATIC  MALE GENITALIA  \
# count       5068.000000    5068.000000  5068.000000     5068.000000
# mean           0.038477       0.076953     0.010655        0.022099
# std            0.192363       0.266544     0.102682        0.147022
# min            0.000000       0.000000     0.000000        0.000000
# 25%            0.000000       0.000000     0.000000        0.000000
# 50%            0.000000       0.000000     0.000000        0.000000
# 75%            0.000000       0.000000     0.000000        0.000000
# max            1.000000       1.000000     1.000000        1.000000
#
#          MATERNITY  MEDIASTINUM  MUSCULOSKELETAL  RESPIRATORY      URINARY
# count  5068.000000  5068.000000      5068.000000  5068.000000  5068.000000
# mean      0.007103     0.002565         0.290845     0.056433     0.057616
# std       0.083990     0.050587         0.454197     0.230778     0.233040
# min       0.000000     0.000000         0.000000     0.000000     0.000000
# 25%       0.000000     0.000000         0.000000     0.000000     0.000000
# 50%       0.000000     0.000000         0.000000     0.000000     0.000000
# 75%       0.000000     0.000000         1.000000     0.000000     0.000000
# max       1.000000     1.000000         1.000000     1.000000     1.000000

# %%
df.shape
# Out:
# (5068, 21)

# %% [markdown]
# <h4>Análisis de correlación</h4>

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

df_numeric = df[df.columns.difference(['HCPCS', 'MODIFIER'])]
df_std = pd.DataFrame(StandardScaler().fit_transform(df_numeric), columns=df_numeric.columns)

df_corr = df_std.corr()
df_corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col1 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col2 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col3 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col4 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col5 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col6 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col7 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col8 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col9 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col10 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col11 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col12 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col13 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col14 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col15 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col16 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col17 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row0_col18 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col0 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col2 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col3 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col4 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col5 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col6 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col7 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col8 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col9 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col10 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col11 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col12 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col13 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col14 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col15 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col16 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col17 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row1_col18 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col0 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col1 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col4 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col5 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col6 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col7 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col8 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col9 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col10 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col11 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col12 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col13 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col14 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col15 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col16 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col17 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row2_col18 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row3_col0 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row3_col1 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_71f81f8a_436b_11e9_983e_28f10e29c841row3_col2 {
#             background-color:  #b40426;

# %% [markdown]
# <h4>Aplicando PCA</h4>

# %%
from sklearn.decomposition import PCA

X = df_std

pca = PCA()
X_pca = pd.DataFrame(pca.fit_transform(X))

explained_variance = pca.explained_variance_ratio_
cum_explained_variance = np.cumsum(explained_variance)

fig = plt.figure()
ax = pd.DataFrame(explained_variance).plot(kind='bar', use_index=True)
ax2 = ax.twinx()
ax2.plot(ax.get_xticks(), pd.DataFrame(cum_explained_variance).values, linestyle='-', marker='o', linewidth=2.0, color='red')
plt.title('Varianza explicada por cada PC')
plt.show()

# %% [markdown]
# <h1>Modelo de clasificación</h1>

# %%
import matplotlib.cm as cmx
import matplotlib.colors as clrs
from mpl_toolkits.mplot3d import Axes3D

def scatter3d(x, y, z, cs, title, xlabel, ylabel, zlabel, cslabel):
    cm = plt.get_cmap('jet')
    cNorm = clrs.Normalize(vmin=min(cs), vmax=max(cs))
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=cm)
    fig = plt.figure()
    ax = Axes3D(fig)
    ax.scatter(x, y, z, c=scalarMap.to_rgba(cs))
    scalarMap.set_array(cs)
    fig.colorbar(scalarMap)
    plt.title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_zlabel(zlabel)
    ax.set_label(cslabel)
    plt.show()

# %%
from pyod.models.knn import KNN
from pyod.models.auto_encoder import AutoEncoder
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(X_pca, test_size=0.3)

contamination = 0.025
clfs = [{'name': 'KNN', 'clf': KNN(contamination=contamination)},
        {'name': 'AutoEncoder', 'clf': AutoEncoder(hidden_neurons=[10, 1, 1, 10],
                                                   verbose=0,
                                                   contamination=contamination)}]

for obj in clfs:
    clf_name = obj['name']
    clf = obj['clf']

    print('============Training model: ' + clf_name + '============')

    clf.fit(X_train)

    y_train_pred = clf.labels_
    y_test_pred = clf.predict(X_test)

    _df_train_class = X_train.assign(y=pd.Series(y_train_pred).values)
    _df_test_class = X_test.assign(y=pd.Series(y_test_pred).values)
    _df = pd.concat([_df_train_class, _df_test_class])

    print('Fraud:', _df[_df.y == 1]['y'].count())
    print('No Fraud:', _df[_df.y == 0]['y'].count())
    scatter3d(_df[0], _df[1], _df[2], _df['y'], clf_name, 'PC0', 'PC1', 'PC2', 'Fraud')
# Out:
# ============Training model: KNN============
# Fraud: 126
# No Fraud: 4942
# ============Training model: AutoEncoder============
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_78 (Dense)             (None, 19)                380
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 19)                0
# _________________________________________________________________
# dense_79 (Dense)             (None, 19)                380
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 19)                0
# _________________________________________________________________
# dense_80 (Dense)             (None, 10)                200
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_81 (Dense)             (None, 1)                 11
# _________________________________________________________________
# dropout_70 (Dropout)         (None, 1)                 0
# _________________________________________________________________
# dense_82 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dropout_71 (Dropout)         (None, 1)                 0
# _________________________________________________________________
# dense_83 (Dense)             (None, 10)                20
# _________________________________________________________________
# dropout_72 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_84 (Dense)             (None, 19)                209
# =================================================================
# Total params: 1,202
# Trainable params: 1,202
# Non-trainable params: 0
# _________________________________________________________________
# None
# Fraud: 113
# No Fraud: 4955
